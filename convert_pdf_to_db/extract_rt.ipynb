# %%
import zipfile
import os
import re
import pandas as pd

# %%
data_folder_path = "data/"

file_paths = []
for folder_path, _, files in os.walk(data_folder_path):
    for file_name in files:
        full_path = os.path.join(folder_path, file_name)
        if('_RT' in file_name):
            europa_number = re.search(r'(\d+)_RT', file_name).group(1)
            file_paths.append({'europa_number': europa_number,
                                  'file_path': full_path})

# %%
#TODO: extract zipfiles and infor from xls
# Out:
# [{'europa_number': '13613', 'file_path': 'data/13613/13613_RT.zip'},
#  {'europa_number': '13045', 'file_path': 'data/13045/13045_RT.zip'},
#  {'europa_number': '13241', 'file_path': 'data/13241/13241_RT.zip'},
#  {'europa_number': '12596', 'file_path': 'data/12596/12596_RT.zip'},
#  {'europa_number': '13223', 'file_path': 'data/13223/13223_RT.zip'},
#  {'europa_number': '12553', 'file_path': 'data/12553/12553_RT.zip'},
#  {'europa_number': '12766', 'file_path': 'data/12766/12766_RT.zip'},
#  {'europa_number': '12537', 'file_path': 'data/12537/12537_RT.zip'},
#  {'europa_number': '12957', 'file_path': 'data/12957/12957_RT.zip'},
#  {'europa_number': '12154', 'file_path': 'data/12154/12154_RT.zip'},
#  {'europa_number': '12995', 'file_path': 'data/12995/12995_RT.zip'},
#  {'europa_number': '12734', 'file_path': 'data/12734/12734_RT.zip'},
#  {'europa_number': '12506', 'file_path': 'data/12506/12506_RT.zip'},
#  {'europa_number': '12992', 'file_path': 'data/12992/12992_RT.zip'},
#  {'europa_number': '13017', 'file_path': 'data/13017/13017_RT.zip'},
#  {'europa_number': '13225', 'file_path': 'data/13225/13225_RT.zip'},
#  {'europa_number': '12555', 'file_path': 'data/12555/12555_RT.zip'},
#  {'europa_number': '12303', 'file_path': 'data/12303/12303_RT.zip'},
#  {'europa_number': '12758', 'file_path': 'data/12758/12758_RT.zip'},
#  {'europa_number': '12552', 'file_path': 'data/12552/12552_RT.zip'},
#  {'europa_number': '13019', 'file_path': 'data/13019/13019_RT.zip'},
#  {'europa_number': '13021', 'file_path': 'data/13021/13021_RT.zip'},
#  {'europa_number': '12751', 'file_path': 'data/12751/12751_RT.zip'},
#  {'europa_number': '12563', 'file_path': 'data/12563/12563_RT.zip'},
#  {'europa_number': '13350', 'file_path': 'data/13350/13350_RT.zip'},
#  {'europa_number': '12418', 'file_path': 'data/12418/12418_RT.zip'},
#  {'europa_number': '13109', 'file_path': 'data/13109/13109_RT.zip'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_big_zoos.xls'},
#  {'europa_number': '287', 'file_path': 'data/287/287/287_RT/287_RT_MSCA.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_big_zoos_anonymous .xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_287_RTZoos_NGOs_experts_name_unregistered.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_MSCA_anonymous.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_Zoo_NGOs_experts-name-registered.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_mid_size_zoos_anonymous .xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_small_zoos.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_Zoo_NGO_experts_anonymous_unregistered.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_Zoos_NGOs_experts_anonymous_registered.xls'},
#  {'europa_number': '287',
#   'file_path': 'data/287/287/287_RT/287_RT_small_zoos_anonymous .xls'},
#  {'europa_number': '13597', 'file_path': 'data/13597/13597_RT.zip'},
#  {'europa_number': '12677', 'file_path': 'data/12677/12677_RT.zip'},
#  {'europa_number': '12648', 'file_path': 'data/12648/12648_RT.zip'},
#  {'europa_number': '12089', 'file_path': 'data/12089/12089_RT.zip'},
#  {'europa_number': '11866', 'file_path': 'data/11866/11866_RT.zip'},
#  {'europa_number': '13164', 'file_path': 'data/13164/13164_RT.zip'},
#  {'europa_number': '13538', 'file_path': 'data/13538/13538_RT.zip'},
#  {'europa_number': '12421', 'file_path': 'data/12421/12421_RT.zip'},
#  {'europa_number': '12870', 'file_path': 'data/12870/12870_RT.zip'},
#  {'europa_number': '12417', 'file_path': 'data/12417/12417_RT.zip'},
#  {'europa_number': '13106', 'file_path': 'data/13106/13106_RT.zip'},
#  {'europa_number': '13334', 'file_path': 'data/13334/13334_RT.zip'},
#  {'europa_number': '12823', 'file_path': 'data/12823/12823_RT.zip'},
#  {'europa_number': '12488', 'file_path': 'data/12488/12488_RT.zip'},
#  {'europa_number': '12475', 'file_path': 'data/12475/12475_RT.zip'},
#  {'europa_number': '13137', 'file_path': 'data/13137/13137_RT.zip'},
#  {'europa_number': '11835', 'file_path': 'data/11835/11835_RT.zip'},
#  {'europa_number': '13108', 'file_path': 'data/13108/13108_RT.zip'},
#  {'europa_number': '423',
#   'file_path': 'data/423/423/423_RT_targeted_stakeholders.xlsx'},
#  {'europa_number': '423', 'file_path': 'data/423/423/423_RT_citizens.xlsx'},
#  {'europa_number': '423',
#   'file_path': 'data/423/423/423_RT_stakeholders.xlsx'},
#  {'europa_number': '401', 'file_path': 'data/401/401/401_RT.xls'},
#  {'europa_number': '12461', 'file_path': 'data/12461/12461_RT.zip'},
#  {'europa_number': '13316', 'file_path': 'data/13316/13316_RT.zip'},
#  {'europa_number': '11886', 'file_path': 'data/11886/11886_RT.zip'},
#  {'europa_number': '12855', 'file_path': 'data/12855/12855_RT.zip'},
#  {'europa_number': '12263', 'file_path': 'data/12263/12263_RT.zip'},
#  {'europa_number': '12636', 'file_path': 'data/12636/12636_RT.zip'},
#  {'europa_number': '12458', 'file_path': 'data/12458/12458_RT.zip'},
#  {'europa_number': '436', 'file_path': 'data/436/436/436_RT_individuals.xls'},
#  {'europa_number': '436',
#   'file_path': 'data/436/436/436_RT_Organisations.xls'},
#  {'europa_number': '12655', 'file_path': 'data/12655/12655_RT.zip'},
#  {'europa_number': '12467', 'file_path': 'data/12467/12467_RT.zip'},
#  {'europa_number': '431', 'file_path': 'data/431/431/431_RT.xls'},
#  {'europa_number': '12494', 'file_path': 'data/12494/12494_RT.zip'},
#  {'europa_number': '12838', 'file_path': 'data/12838/12838_RT.zip'},
#  {'europa_number': '12664', 'file_path': 'data/12664/12664_RT.zip'},
#  {'europa_number': '12663', 'file_path': 'data/12663/12663_RT.zip'},
#  {'europa_number': '12637', 'file_path': 'data/12637/12637_RT.zip'},
#  {'europa_number': '12061', 'file_path': 'data/12061/12061_RT.zip'},
#  {'europa_number': '454', 'file_path': 'data/454/454/454_RT.pdf'},
#  {'europa_number': '1530', 'file_path': 'data/1530/1530_RT.pdf'},
#  {'europa_number': '12265', 'file_path': 'data/12265/12265_RT.zip'},
#  {'europa_number': '7567584', 'file_path': 'data/7567584/7567584_RT.zip'},
#  {'europa_number': '12579', 'file_path': 'data/12579/12579_RT.zip'},
#  {'europa_number': '12310', 'file_path': 'data/12310/12310_RT.zip'},
#  {'europa_number': '12774', 'file_path': 'data/12774/12774_RT.zip'},
#  {'europa_number': '12780', 'file_path': 'data/12780/12780_RT.zip'},
#  {'europa_number': '12114', 'file_path': 'data/12114/12114_RT.zip'},
#  {'europa_number': '13238', 'file_path': 'data/13238/13238_RT.zip'},
#  {'europa_number': '12548', 'file_path': 'data/12548/12548_RT.zip'},
#  {'europa_number': '12910', 'file_path': 'data/12910/12910_RT.zip'},
#  {'europa_number': '12381', 'file_path': 'data/12381/12381_RT.zip'},
#  {'europa_number': '13509', 'file_path': 'data/13059/13509_RT.zip'},
#  {'europa_number': '12975', 'file_path': 'data/12975/12975_RT.zip'},
#  {'europa_number': '13601', 'file_path': 'data/13601/13601_RT.zip'},
#  {'europa_number': '12911', 'file_path': 'data/12911/12911_RT.zip'},
#  {'europa_number': '13206', 'file_path': 'data/13206/13206_RT.zip'},
#  {'europa_number': '12916', 'file_path': 'data/12916/12916_RT.zip'},
#  {'europa_number': '13665', 'file_path': 'data/13665/13665_RT.zip'},
#  {'europa_number': '12772', 'file_path': 'data/12772/12772_RT.zip'},
#  {'europa_number': '12726', 'file_path': 'data/12726/12726_RT.zip'},
#  {'europa_number': '11965', 'file_path': 'data/11965/11965_RT.zip'},
#  {'europa_number': '13058', 'file_path': 'data/13058/13058_RT.zip'},
#  {'europa_number': '12592', 'file_path': 'data/12592/12592_RT.zip'},
#  {'europa_number': '11548', 'file_path': 'data/11548/11548_RT.zip'},
#  {'europa_number': '12963', 'file_path': 'data/12963/12963_RT.zip'},
#  {'europa_number': '12790', 'file_path': 'data/12790/12790_RT.zip'},
#  {'europa_number': '2018', 'file_path': 'data/2018/2018_RT.csv'},
#  {'europa_number': '12931', 'file_path': 'data/12931/12931_RT.zip'},
#  {'europa_number': '12567', 'file_path': 'data/12567/12567_RT.zip'},
#  {'europa_number': '13217', 'file_path': 'data/13217/13217_RT.zip'},
#  {'europa_number': '12398', 'file_path': 'data/12398/12398_RT.zip'},
#  {'europa_number': '2080', 'file_path': 'data/2080/2080_RT.zip'},
#  {'europa_number': '12737', 'file_path': 'data/12737/12737_RT.zip'},
#  {'europa_number': '419', 'file_path': 'data/419/419/419_RT.pdf'},
#  {'europa_number': '12483', 'file_path': 'data/12483/12483_RT.zip'},
#  {'europa_number': '11837', 'file_path': 'data/11837/11837_RT.zip'},
#  {'europa_number': '13338', 'file_path': 'data/13338/13338_RT.zip'},
#  {'europa_number': '12674', 'file_path': 'data/12674/12674_RT.zip'},
#  {'europa_number': '12479', 'file_path': 'data/12479/12479_RT.zip'},
#  {'europa_number': '13331', 'file_path': 'data/13331/13331_RT.zip'},
#  {'europa_number': '410', 'file_path': 'data/410/410/410_RT.xls'},
#  {'europa_number': '12228', 'file_path': 'data/12228/12228_RT.zip'},
#  {'europa_number': '13168', 'file_path': 'data/13168/13168_RT.zip'},
#  {'europa_number': '13396', 'file_path': 'data/13396/13396_RT.zip'},
#  {'europa_number': '13150', 'file_path': 'data/13150/13150_RT.zip'},
#  {'europa_number': '12844', 'file_path': 'data/12844/12844_RT.zip'},
#  {'europa_number': '12827', 'file_path': 'data/12827/12827_RT.zip'},
#  {'europa_number': '411', 'file_path': 'data/411/411/411_RT.xls'},
#  {'europa_number': '2136', 'file_path': 'data/2136/2136_RT.zip'},
#  {'europa_number': '12227', 'file_path': 'data/12227/12227_RT.zip'},
#  {'europa_number': '13134', 'file_path': 'data/13134/13134_RT.zip'},
#  {'europa_number': '11865', 'file_path': 'data/11865/11865_RT.zip'},
#  {'europa_number': '2154', 'file_path': 'data/2154/2154_RT.zip'},
#  {'europa_number': '12621', 'file_path': 'data/12621/12621_RT.zip'},
#  {'europa_number': '12413', 'file_path': 'data/12413/12413_RT.zip'},
#  {'europa_number': '2140', 'file_path': 'data/2140/2140_RT.zip'},
#  {'europa_number': '12251', 'file_path': 'data/12251/12251_RT.zip'},
#  {'europa_number': '12438', 'file_path': 'data/12438/12438_RT.zip'},
#  {'europa_number': '12632', 'file_path': 'data/12632/12632_RT.zip'},
#  {'europa_number': '12400', 'file_path': 'data/12400/12400_RT.zip'},
#  {'europa_number': '13142', 'file_path': 'data/13142/13142_RT.zip'},
#  {'europa_number': '12090', 'file_path': 'data/12090/12090_RT.zip'},
#  {'europa_number': '12454', 'file_path': 'data/12454/12454_RT.zip'},
#  {'europa_number': '13116', 'file_path': 'data/13116/13116_RT.zip'},
#  {'europa_number': '402', 'file_path': 'data/402/402/402_RT.xls'},
#  {'europa_number': '12453', 'file_path': 'data/12453/12453_RT.zip'},
#  {'europa_number': '12491', 'file_path': 'data/12491/12491_RT.zip'},
#  {'europa_number': '12657', 'file_path': 'data/12657/12657_RT.zip'},
#  {'europa_number': '12465', 'file_path': 'data/12465/12465_RT.zip'},
#  {'europa_number': '12633', 'file_path': 'data/12633/12633_RT.zip'},
#  {'europa_number': '12364', 'file_path': 'data/12634/12364_RT.zip'},
#  {'europa_number': '2148', 'file_path': 'data/2148/2148_RT.zip'},
#  {'europa_number': '13186', 'file_path': 'data/13186/13186_RT.zip'},
#  {'europa_number': '13172', 'file_path': 'data/13172/13172_RT.zip'},
#  {'europa_number': '13181', 'file_path': 'data/13181/13181_RT.zip'},
#  {'europa_number': '12098', 'file_path': 'data/12098/12098_RT.zip'},
#  {'europa_number': '12463', 'file_path': 'data/12463/12463_RT.zip'},
#  {'europa_number': '12803', 'file_path': 'data/12803/12803_RT.zip'},
#  {'europa_number': '13119', 'file_path': 'data/13119/13119_RT.zip'},
#  {'europa_number': '12464', 'file_path': 'data/12464/12464_RT.zip'},
#  {'europa_number': '12656', 'file_path': 'data/12656/12656_RT.zip'},
#  {'europa_number': '12660', 'file_path': 'data/12660/12660_RT.zip'},
#  {'europa_number': '11815', 'file_path': 'data/11815/11815_RT (2).zip'},
#  {'europa_number': '11815', 'file_path': 'data/11815/11815_RT.zip'},
#  {'europa_number': '13117', 'file_path': 'data/13117/13117_RT.zip'},
#  {'europa_number': '12527', 'file_path': 'data/12527/12527_RT.zip'},
#  {'europa_number': '12382', 'file_path': 'data/12382/12382_RT.zip'},
#  {'europa_number': '12376', 'file_path': 'data/12376/12376_RT.zip'},
#  {'europa_number': '12724', 'file_path': 'data/12724/12724_RT.zip'},
#  {'europa_number': '12340', 'file_path': 'data/12340/12340_RT.zip'},
#  {'europa_number': '12511', 'file_path': 'data/12511/12511_RT.zip'},
#  {'europa_number': '13463', 'file_path': 'data/13463/13463_RT.zip'},
#  {'europa_number': '12779', 'file_path': 'data/12779/12779_RT.zip'},
#  {'europa_number': '12325', 'file_path': 'data/12325/12325_RT.zip'},
#  {'europa_number': '13031', 'file_path': 'data/13031/13031_RT.zip'},
#  {'europa_number': '12722', 'file_path': 'data/12722/12722_RT.zip'},
#  {'europa_number': '12517', 'file_path': 'data/12517/12517_RT.zip'},
#  {'europa_number': '11968', 'file_path': 'data/11968/11968_RT.xls'},
#  {'europa_number': '12979', 'file_path': 'data/12979/12979_RT.zip'},
#  {'europa_number': '12129', 'file_path': 'data/12129/12129_RT.zip'},
#  {'europa_number': '386', 'file_path': 'data/386/386/386_RT_targeted.xls'},
#  {'europa_number': '386', 'file_path': 'data/386/386/386_RT_open.xls'},
#  {'europa_number': '386',
#   'file_path': 'data/386/386/386_RT_consumer organizations.xls'},
#  {'europa_number': '12111', 'file_path': 'data/12111/12111_RT.zip'},
#  {'europa_number': '12588', 'file_path': 'data/12588/12588_RT.zip'},
#  {'europa_number': '13491', 'file_path': 'data/13491/13491_RT.zip'},
#  {'europa_number': '13462', 'file_path': 'data/13462/13462_RT.zip'},
#  {'europa_number': '12312', 'file_path': 'data/12312/12312_RT.zip'}]
